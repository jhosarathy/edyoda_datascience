# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
cols = ['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship'
        ,'race','sex','capital-gain','capital-loss','hours-per-week','native-country','Salary']
adult_data = pd.read_csv('https://raw.githubusercontent.com/edyoda/data-science-complete-tutorial/master/Data/adult.data.txt', names=cols)

# %%
df = adult_data

# %%
### Load data
*

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  Salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### Addressing "Take care of missing values marked by '?'"

# %%
for item in cols:
    if(df[item].dtypes == df['Salary'].dtypes):
        df.drop(df[df[item].str.match('\s*\?\s*')].index, inplace=True)

# %%
df.tail()
# Out:
#        age      workclass  fnlwgt    education  education-num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation relationship    race      sex  \
# 32556   Married-civ-spouse        Tech-support         Wife   White   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32558              Widowed        Adm-clerical    Unmarried   White   Female
# 32559        Never-married        Adm-clerical    Own-child   White     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        capital-gain  capital-loss  hours-per-week  native-country  Salary
# ...

# %% [markdown]
# ### No of records
# * No of records present
# * The number of individuals making more or less than 50k etc, will show us how many individuals fit in each group.

# %%
n_records = df.shape[0]
n_greater_50k = df[df['Salary'] == ' >50K'].shape[0]
n_atmost_50k = df[df['Salary'] == ' <=50K'].shape[0]
print("No.of records present:", n_records)
print("No.of individuals making more than 50k:", n_greater_50k)
print("No.of individuals making less than or equal to 50k:", n_atmost_50k)
# Out:
# No.of records present: 30162
# No.of individuals making more than 50k: 7508
# No.of individuals making less than or equal to 50k: 22654

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2cce3448b0>,
# ...
#       dtype=object)

# %%
from sklearn.preprocessing import MinMaxScaler
df_tran = pd.DataFrame(data = df)
numerical = ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
df_tran[numerical] = MinMaxScaler().fit_transform(df[numerical])

# %%
objects
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'Salary']

# %%
objects = []
for col in cols:
    if df[col].dtypes == df['Salary'].dtypes:
        objects.append(col)
from sklearn.preprocessing import LabelEncoder
for i in objects:
    df_tran[i] = LabelEncoder().fit_transform(df[i])

# %%
df_tran.tail()
# Out:
#             age  workclass    fnlwgt  education  education-num  \
# 32556  0.136986          2  0.165563          7       0.733333
# 32557  0.315068          2  0.095589         11       0.533333
# 32558  0.561644          2  0.093914         11       0.533333
# 32559  0.068493          2  0.127620         11       0.533333
# 32560  0.479452          3  0.186383         11       0.533333
#
#        marital-status  occupation  relationship  race  sex  capital-gain  \
# 32556               2          12             5     4    0      0.000000
# 32557               2           6             0     4    1      0.000000
# 32558               6           0             4     4    0      0.000000
# 32559               4           0             3     4    1      0.000000
# 32560               2           3             5     4    0      0.150242
#
#        capital-loss  hours-per-week  native-country  Salary
# 32556           0.0        0.377551              38       0
# ...

# %%
df_tran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30162 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30162 non-null  float64
#  1   workclass       30162 non-null  int64
#  2   fnlwgt          30162 non-null  float64
#  3   education       30162 non-null  int64
#  4   education-num   30162 non-null  float64
#  5   marital-status  30162 non-null  int64
#  6   occupation      30162 non-null  int64
#  7   relationship    30162 non-null  int64
#  8   race            30162 non-null  int64
#  9   sex             30162 non-null  int64
#  10  capital-gain    30162 non-null  float64
#  11  capital-loss    30162 non-null  float64
#  12  hours-per-week  30162 non-null  float64
#  13  native-country  30162 non-null  int64
#  14  Salary          30162 non-null  int64
# dtypes: float64(6), int64(9)
# memory usage: 4.9 MB

# %%
features = df_tran.iloc[:, :-1]

# %%
features
# Out:
#             age  workclass    fnlwgt  education  education-num  \
# 0      0.301370          5  0.043338          9       0.800000
# 1      0.452055          4  0.047277          9       0.800000
# 2      0.287671          2  0.137244         11       0.533333
# 3      0.493151          2  0.150212          1       0.400000
# 4      0.150685          2  0.220703          9       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986          2  0.165563          7       0.733333
# 32557  0.315068          2  0.095589         11       0.533333
# 32558  0.561644          2  0.093914         11       0.533333
# 32559  0.068493          2  0.127620         11       0.533333
# 32560  0.479452          3  0.186383         11       0.533333
#
#        marital-status  occupation  relationship  race  sex  capital-gain  \
# 0                   4           0             1     4    1      0.021740
# ...

# %%
target = df_tran.iloc[:, -1:]

# %%
target
# Out:
#        Salary
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 32556       0
# 32557       1
# 32558       0
# 32559       0
# 32560       1
#
# [30162 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
trainX, testX, trainY, testY = train_test_split(features, target, train_size = 0.3 )

# %%
from sklearn.neighbors import KNeighborsClassifier
knnc = KNeighborsClassifier()
knnc.fit(trainX,trainY)
knnc.score(testX, testY)
# Out:
# <ipython-input-90-e523d7cd6bcb>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   knnc.fit(trainX,trainY)
# 0.810268068580089

# %%
knnc.score(testX, testY)
# Out:
# 0.8268447475608601
